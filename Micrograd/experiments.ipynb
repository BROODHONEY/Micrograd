# %%
import engine
import nn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %% [markdown]
# # Experimenting with our Micrograd

# %% [markdown]
# ###
